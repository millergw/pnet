# %%
import logging
import pandas as pd
import os
import yaml

# %% [markdown]
# # Constructing simulated data
# Make new config files needed to run wandb sweep on the perturbed data: a sweep config YAML and a YAML with the perturbed data and perturbed target pairs (similar to how we have a data.yaml with all the normal genetic data).

# %% [markdown]
# ### Extended control_freqs
# Step 1: update the dictionary of perturbed_data file names
# Step 2: create new wandb sweep YAML file

# %%
# reduced number of features in the perturbed somatic_mut DF to test importance of initial feature selection in preprocessing
WANDB_RUN = "8b3qnf2v" 
perturbed_data_config_path = "/mnt/disks/gmiller_data1/pnet/configs/perturbed_data-somatic_mut-n_features.yaml"
sweep_config_path = "/mnt/disks/gmiller_data1/pnet/configs/sweep_perturbed_data-somatic_mut-n_features.yaml"

sweep_config_path = "/mnt/disks/gmiller_data1/pnet/configs/sweep_perturbed_data-somatic_mut-n_features-only3seeds.yaml"

# Extended control_freqs on perturbed somatic_mut
# WANDB_RUN = "xiq2m609" 
# perturbed_data_config_path = "/mnt/disks/gmiller_data1/pnet/configs/perturbed_data-somatic_mut-extended_control_freqs.yaml"
# sweep_config_path = "/mnt/disks/gmiller_data1/pnet/configs/sweep_perturbed_data-somatic_mut-extended_control_freqs.yaml"

# WANDB_RUN = "mqivqsdi" # Initial OR x control_freq ranges on perturbed somatic_mut

# %%
# Path to the perturbation summary CSV
summary_csv_path = f"../../pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-{WANDB_RUN}/perturbation_summary_{WANDB_RUN}.csv"

# Load the perturbation summary CSV
summary_df = pd.read_csv(summary_csv_path)

# Create a dictionary for the YAML file
perturbed_data_dict = {
    "perturbed_somatic_mut": {
        os.path.splitext(os.path.basename(row["out_data_file"]))[0].replace("somatic_mut_", ""): {
            "data_file": os.path.basename(row["out_data_file"]),
            "target_file": os.path.basename(row["out_target_file"]),
        }
        for _, row in summary_df.iterrows()
    }
}

# Save the dictionary to a YAML file
with open(perturbed_data_config_path, "w") as yaml_file:
    yaml.dump(perturbed_data_dict, yaml_file, default_flow_style=False)

print(f"perturbed data pairs YAML file saved to {perturbed_data_config_path}")
# Out:
# perturbed data pairs YAML file saved to /mnt/disks/gmiller_data1/pnet/configs/perturbed_data-somatic_mut-n_features.yaml

# %%
summary_csv_path = f"../../pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-{WANDB_RUN}/perturbation_summary_{WANDB_RUN}.csv"

summary_df = pd.read_csv(summary_csv_path)
summary_df = summary_df[summary_df["control_freq"]==0.01]
summary_df
# Out:
#                                                suffix  \
# 4   gene-AR_OR-1_ctrlFreq-0p01_caseFreq-0p01_nFeat...
# 5   gene-AR_OR-1p1_ctrlFreq-0p01_caseFreq-0p011_nF...
# 6   gene-AR_OR-2_ctrlFreq-0p01_caseFreq-0p02_nFeat...
# 7   gene-AR_OR-10_ctrlFreq-0p01_caseFreq-0p1_nFeat...
# 28  gene-AR_OR-1_ctrlFreq-0p01_caseFreq-0p01_nFeat...
# 29  gene-AR_OR-1p1_ctrlFreq-0p01_caseFreq-0p011_nF...
# 30  gene-AR_OR-2_ctrlFreq-0p01_caseFreq-0p02_nFeat...
# 31  gene-AR_OR-10_ctrlFreq-0p01_caseFreq-0p1_nFeat...
# 52  gene-AR_OR-1_ctrlFreq-0p01_caseFreq-0p01_nFeat...
# 53  gene-AR_OR-1p1_ctrlFreq-0p01_caseFreq-0p011_nF...
# 54  gene-AR_OR-2_ctrlFreq-0p01_caseFreq-0p02_nFeat...
# 55  gene-AR_OR-10_ctrlFreq-0p01_caseFreq-0p1_nFeat...
#
#                                         out_data_file  \
# 4   /mnt/disks/gmiller_data1/pnet_germline/process...
# 5   /mnt/disks/gmiller_data1/pnet_germline/process...
# 6   /mnt/disks/gmiller_data1/pnet_germline/process...
# 7   /mnt/disks/gmiller_data1/pnet_germline/process...
# 28  /mnt/disks/gmiller_data1/pnet_germline/process...
# 29  /mnt/disks/gmiller_data1/pnet_germline/process...
# 30  /mnt/disks/gmiller_data1/pnet_germline/process...
# 31  /mnt/disks/gmiller_data1/pnet_germline/process...
# 52  /mnt/disks/gmiller_data1/pnet_germline/process...
# 53  /mnt/disks/gmiller_data1/pnet_germline/process...
# 54  /mnt/disks/gmiller_data1/pnet_germline/process...
# 55  /mnt/disks/gmiller_data1/pnet_germline/process...
#
#                                       out_target_file gene  control_freq  \
# 4   /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 5   /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 6   /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 7   /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 28  /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 29  /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 30  /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 31  /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 52  /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 53  /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 54  /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
# 55  /mnt/disks/gmiller_data1/pnet_germline/process...   AR          0.01
#
#     case_freq  odds_ratio  n_case_flips  n_control_flips  n_case  n_control  \
# 4       0.010         1.0             4                4     471        472
# 5       0.011         1.1             5                4     471        472
# 6       0.020         2.0             9                4     471        472
# 7       0.100        10.0            47                4     471        472
# 28      0.010         1.0             4                4     471        472
# 29      0.011         1.1             5                4     471        472
# 30      0.020         2.0             9                4     471        472
# 31      0.100        10.0            47                4     471        472
# 52      0.010         1.0             4                4     471        472
# 53      0.011         1.1             5                4     471        472
# 54      0.020         2.0             9                4     471        472
# 55      0.100        10.0            47                4     471        472
#
#     n_features wandb_run_id
# 4           10     8b3qnf2v
# 5           10     8b3qnf2v
# 6           10     8b3qnf2v
# 7           10     8b3qnf2v
# 28         100     8b3qnf2v
# 29         100     8b3qnf2v
# 30         100     8b3qnf2v
# 31         100     8b3qnf2v
# 52        1000     8b3qnf2v
# 53        1000     8b3qnf2v
# 54        1000     8b3qnf2v
# 55        1000     8b3qnf2v

# %%
# Create wandb sweep YAML config file
summary_csv_path = (
    f"/mnt/disks/gmiller_data1/pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-{WANDB_RUN}/perturbation_summary_{WANDB_RUN}.csv"
)
data_split_dir = f"/mnt/disks/gmiller_data1/pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-{WANDB_RUN}"
perturbed_data_dir = f"/mnt/disks/gmiller_data1/pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-{WANDB_RUN}"
perturbed_data_wandb_id = WANDB_RUN  # The wandb run ID for the perturbed data
input_data_wandb_id = "u5yt90p1"  # The wandb run ID for the input data (not sure if I am using any)
input_data_dir = "/mnt/disks/gmiller_data1/pnet_germline/processed/wandb-group-data_prep_germline_tier12_and_somatic/converted-IDs-to-somatic_imputed-germline_True_imputed-somatic_False_paired-samples-True/wandb-run-id-u5yt90p1"
input_data_config_f = "/mnt/disks/gmiller_data1/pnet/configs/data.yaml"

summary_df = pd.read_csv(summary_csv_path)

sweep_config = {
    "program": "/mnt/disks/gmiller_data1/pnet/src/pnet/run_model_on_perturbed_data.py",
    "method": "grid",
    "parameters": {
        "datasets": {"value": "somatic_mut"},
        "perturbed_data_dir": {"value": perturbed_data_dir},
        "perturbed_data_wandb_id": {"value": perturbed_data_wandb_id},
        "perturbed_data_config_f": {"value": perturbed_data_config_path},
        "data_config_f": {"value": input_data_config_f},
        "evaluation_set": {"values": ["validation"]},
        "model_type": {"values": ["rf", "pnet"]},
        "wandb_group": {"value": "pnet_perturbed_data"},
        "wandb_project": {"value": "prostate_met_status"},
        "seed": {"values": [123, 42, 155]},
        "input_data_wandb_id": {"value": input_data_wandb_id},
        "input_data_dir": {"value": input_data_dir},
        "cpus": {"value": 2},
        "perturbation_suffix": {
            "values": [
                os.path.splitext(os.path.basename(row["out_data_file"]))[0].replace("somatic_mut_", "")
                for _, row in summary_df.iterrows()
            ]
        },
    }
}

with open(sweep_config_path, "w") as f:
    yaml.dump(sweep_config, f)
print(f"wandb sweep YAML file saved to {sweep_config_path}")
# Out:
# wandb sweep YAML file saved to /mnt/disks/gmiller_data1/pnet/configs/sweep_perturbed_data-somatic_mut-n_features-only3seeds.yaml

# %% [markdown]
# ### First sweep: reasonable range of OR and control_frequencies on somatic_mut

# %%
# Creat a perturbed_data.yaml config file for the perturbed data+target combinations indexed by the suffix of the data file
import pandas as pd
import os
import yaml

# Path to the perturbation summary CSV
summary_csv_path = "../../pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-mqivqsdi/perturbation_summary_mqivqsdi.csv"

# Load the perturbation summary CSV
summary_df = pd.read_csv(summary_csv_path)

# Create a dictionary for the YAML file
perturbed_data_dict = {
    "perturbed_somatic_mut": {
        os.path.splitext(os.path.basename(row["out_data_file"]))[0].replace("somatic_mut_", ""): {
            "data_file": os.path.basename(row["out_data_file"]),
            "target_file": os.path.basename(row["out_target_file"]),
        }
        for _, row in summary_df.iterrows()
    }
}

# Save the dictionary to a YAML file
output_yaml_path = "/mnt/disks/gmiller_data1/pnet/configs/perturbed_data.yaml"
with open(output_yaml_path, "w") as yaml_file:
    yaml.dump(perturbed_data_dict, yaml_file, default_flow_style=False)

print(f"YAML file saved to {output_yaml_path}")
# Out:
# YAML file saved to /mnt/disks/gmiller_data1/pnet/configs/perturbed_data.yaml

# %%
# Create wandb sweep YAML config file
import pandas as pd
import yaml

summary_csv_path = (
    "/mnt/disks/gmiller_data1/pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-mqivqsdi/perturbation_summary_mqivqsdi.csv"
)

data_split_dir = "/mnt/disks/gmiller_data1/pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-mqivqsdi"
perturbed_data_dir = "/mnt/disks/gmiller_data1/pnet_germline/processed/perturbed_genotype_datasets/p1000_somatic_mut/wandb-run-id-mqivqsdi"
perturbed_data_wandb_id = "mqivqsdi"  # The wandb run ID for the perturbed data
input_data_wandb_id = "u5yt90p1"  # The wandb run ID for the input data (not sure if I am using any)
input_data_dir = "/mnt/disks/gmiller_data1/pnet_germline/processed/wandb-group-data_prep_germline_tier12_and_somatic/converted-IDs-to-somatic_imputed-germline_True_imputed-somatic_False_paired-samples-True/wandb-run-id-u5yt90p1"

df = pd.read_csv(summary_csv_path)
sweep_config = {
    "program": "run_model_on_perturbed_data.py",
    "method": "grid",
    "parameters": {
        "datasets": {"value": "somatic_mut"},
        "perturbed_data_dir": {"value": f"{perturbed_data_dir}"},
        "perturbed_data_wandb_id": {"value": f"{perturbed_data_wandb_id}"},
        "perturbed_data_config_f": {"value": "/mnt/disks/gmiller_data1/pnet/configs/perturbed_data.yaml"},
        "data_config_f": {"value": "/mnt/disks/gmiller_data1/pnet/configs/data.yaml"},
        "evaluation_set": {"values": ["validation"]},
        "model_type": {"values": ["pnet", "rf"]},
        "wandb_group": {"value": "pnet_perturbed_data"},
        "wandb_project": {"value": "prostate_met_status"},
        "seed": {"values": [123, 42, 155, 23, 356]},
        "input_data_wandb_id": {"value": f"{input_data_wandb_id}"},
        "input_data_dir": {"value": f"{input_data_dir}"},
        "cpus": {"value": 2},
        "perturbation_suffix": {
            "values": [
                os.path.splitext(os.path.basename(row["out_data_file"]))[0].replace("somatic_mut_", "")
                for _, row in df.iterrows()
            ]
        },
    }
}

with open("../configs/sweep_perturbed_somatic_mut.yaml", "w") as f:
    yaml.dump(sweep_config, f)
